# %% [markdown]
# ![Work Report](../image/baner/Untitled-1.jpg)
# ## **📅 تاریخ: 23 آبان 1404**
#
# ---
# ### ✨ کارهای انجام‌شده:
# - HTML Event
#
# ### 📈 یادداشت‌ها:
# - انواع event ها در html:
#     - onchange[Go to code](#code-1)
#     - onclick[Go to code](#code-2)
#     - onmouseover[Go to code](#code-3)
#     - onmouseout[Go to code](#code-4)
#     - onkeydown[Go to code](#code-5)
#     - onload[Go to code](#code-6)
#
# ---
# ## code-1
# ![code1](../image/Day%2010/code.png)
#
# ---
# ## code-2
# ![code1](../image/Day%2010/code2.png)
#
# ---
# ## code-3
# ![code1](../image/Day%2010/code3.png)
#
# ---
# ## code-4
# ![code1](../image/Day%2010/code4.png)
#
# ---
# ## code-5
# ![code1](../image/Day%2010/code5.png)
#
# ---
# ## code-6
# ![code1](../image/Day%2010/code6.png)

# %% [markdown]
# # 📝 Work Report
# 📅 تاریخ: 12 آبان 1404
#
# ---
# ### ✨ کارهای انجام‌شده:
# - متغیرها و انواع داده ها در جاوا اسکریپت
#
# ### 📈 یادداشت‌ها:
# -  در این قسمت با موارد زیر آشنا شدم:
# 1. عنواع داده
# 2. value
# 3. object
# 4. Array
# 5. concat
# 6. Undefiued - Empty - Null
#
#
# - ## code-1
# ![توضیح عکس](../image/Day%203/jscode.png)
#
# ---
# - ## code-2
# ![توضیح عکس](../image/Day%203/jscode2.png)
#
# ---
# - ## code-3
# ![توضیح عکس](../image/Day%203/jscode3.png)
#
# ---
# - ## code-4
# ![توضیح عکس](../image/Day%203/jscode4.png)
